# %%
import pandas as pd
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#read each sheet separately
books = pd.read_excel('library.xlsx', sheet_name='All Books Database')
check_in = pd.read_excel('library.xlsx', sheet_name='Books Checked in')
check_out = pd.read_excel('library.xlsx', sheet_name='Books Checked out ')
students = pd.read_excel('library.xlsx', sheet_name="All students Database")

# %%
#getting the list of sheets without reading the excel file first
xl = pd.ExcelFile('library.xlsx')

sheet_list = xl.sheet_names  # see all sheet names


#loop through the list making a frame from each
frame_list = ['books', 'check_in', 'check_out', 'students']

count= 0
for sheet in sheet_list:
    frame_list[count] = pd.read_excel('library.xlsx', sheet_name=sheet)
    count += count

# %%
for x in books.columns:
    print(x)
# Out:
# Author
# Book Title
# Age
# Age Group
# Copies
# Category
# Notes
# Brought By:
# ALL BOOKS INVENTORY
# Unnamed: 9

# %%
for x in check_in.columns:
    print(x)
# Out:
# Timestamp
# Student Name
# Class Level
# Book Title
# Book Category
# Check Out Duration

# %%
for x in check_out.columns:
    print(x)
# Out:
# Timestamp
# Student Name
# Class Level
# Book Title
# Book Category
# Check out Duration
# Book Title.1
# Book Category.1
# Unnamed: 8
# Total Books Checked Out
# 1575
# Unnamed: 11
# Unnamed: 12

# %%
for x in students.columns:
    print(x)
# Out:
# Child: Child Last, First Name
# Age
# Gender
# Child's Status
# Date entered program
# Grammar Class of
# Secondary Class of:
# Enrollment Type CY
# Class Level CY

# %%
import matplotlib.pyplot as plt

plt.hist(students.Age, bins=33)
# Out:
# (array([ 1.,  1.,  0.,  5.,  0., 18.,  0., 26.,  0., 17.,  0., 26., 20.,
#          0., 32.,  0., 14.,  0., 26.,  0., 44.,  0., 16., 33.,  0., 30.,
#          0., 23.,  0., 18.,  0., 14.,  3.]),
#  array([ 6.        ,  6.54545455,  7.09090909,  7.63636364,  8.18181818,
#          8.72727273,  9.27272727,  9.81818182, 10.36363636, 10.90909091,
#         11.45454545, 12.        , 12.54545455, 13.09090909, 13.63636364,
#         14.18181818, 14.72727273, 15.27272727, 15.81818182, 16.36363636,
#         16.90909091, 17.45454545, 18.        , 18.54545455, 19.09090909,
#         19.63636364, 20.18181818, 20.72727273, 21.27272727, 21.81818182,
#         22.36363636, 22.90909091, 23.45454545, 24.        ]),
#  <BarContainer object of 33 artists>)

# %%
books
# Out:
#                         Author                   Book Title  Age  \
# 0                  Mezrich Ben                           21  3.0
# 1               margret Malcom                   I can read  1.0
# 2        Rigby PM collections                           Mom  1.0
# 3             Michele Dufresne                 We like Hats  1.0
# 4                           DK  100 People who made history  4.0
# ...                        ...                          ...  ...
# 2959  Victor Mayer-Schonberger                     Big Data  4.0
# 2960           Steven D levitt                 Freakonomics  4.0
# 2961            Charles Duhigg          The power of habbit  4.0
# 2962         Kinyanjui Komboni              Eve's Invention  3.0
# 2963         Kinyanjui Komboni                     Do or do  3.0
#
#                 Age Group  Copies            Category        Notes  \
# 0                    9-12     NaN             Fiction  Mezrich Ben
# 1                     0-4     NaN        Early leader          NaN
# 2                     0-4     2.0        Early leader          NaN
# 3                     0-4     NaN        Early leader          NaN
# 4                   13-17     NaN      Social Studies          NaN
# ...                   ...     ...                 ...          ...
# 2959                13-17     NaN             Science          NaN
# 2960                13-17     NaN    Self improvement          NaN
# 2961                  NaN     NaN    Self improvement          NaN
# 2962  2019-09-12 00:00:00     9.0  African literature   Judy Nyaga
# 2963  2019-09-12 00:00:00     9.0  African literature   Judy Nyaga
#
#          Brought By: ALL BOOKS INVENTORY Unnamed: 9
# 0                NaN       Book Category   Total No
# 1     Susan Plimpton                 NaN        NaN
# 2     Susan Plimpton                 NaN        NaN
# 3     Susan Plimpton                 NaN        NaN
# 4                NaN             Fiction       1321
# ...              ...                 ...        ...
# 2959             NaN                 NaN        NaN
# 2960             NaN                 NaN        NaN
# 2961             NaN                 NaN        NaN
# 2962             NaN                 NaN        NaN
# 2963             NaN                 NaN        NaN
#
# [2964 rows x 10 columns]

# %%
students
# Out:
#     Child: Child Last, First Name   Age  Gender   Child's Status  \
# 0                    Auma, Flavia  23.0  Female  Grant Sponsored
# 1                     Mumo, Faith  21.0  Female  Grant Sponsored
# 2                  Wanjiku, Emily  22.0  Female  Grant Sponsored
# 3                Achieng, Cynthia  21.0  Female        Sponsored
# 4                  Achieng, Fenny  21.0  Female        Sponsored
# ..                            ...   ...     ...              ...
# 376                           NaN   NaN     NaN              NaN
# 377                           NaN   NaN     NaN              NaN
# 378                           NaN   NaN     NaN              NaN
# 379                           NaN   NaN     NaN              NaN
# 380                           NaN   NaN     NaN              NaN
#
#     Date entered program  Grammar Class of  Secondary Class of:  \
# 0             2007-09-03            2010.0               2014.0
# 1             2008-02-21            2010.0               2014.0
# 2             2006-03-17            2010.0               2014.0
# 3             2011-03-23            2014.0               2018.0
# 4             2009-04-15            2014.0               2018.0
# ..                   ...               ...                  ...
# 376                  NaT               NaN                  NaN
# 377                  NaT               NaN                  NaN
# 378                  NaT               NaN                  NaN
# 379                  NaT               NaN                  NaN
# 380                  NaT               NaN                  NaN
#
#     Enrollment Type CY Class Level CY
# 0               Alumni         Alumni
# 1               Alumni         Alumni
# 2               Alumni         Alumni
# 3       Post Secondary    Certificate
# 4       Post Secondary    Certificate
# ..                 ...            ...
# 376                NaN            NaN
# 377                NaN            NaN
# 378                NaN            NaN
# 379                NaN            NaN
# 380                NaN            NaN
#
# [381 rows x 9 columns]
