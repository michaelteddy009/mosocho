# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Python Programming: Bayesian Estimation Exercise

# %% [markdown]
# ## Examples

# %%
# Example 1
# ---
# Determine the bias of a Thumbtack 
# (A thumbtack is a short flat-headed pin, used for fastening paper to a wall or other surface.)
# ---
# 

# We shall use the excellent PyMC library. Let's install it
# We shall avoid going into the finer details of PyMC. Excellent documentation for PyMC 
# can be found both in the PyMC docs as well as the book "Probabilistic Programming and Bayesian methods for Hackers" 
# by Cam Davidson-Pilon's, which can be found online at 
# http://camdavidsonpilon.github.io/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/.
#!pip install pymc
# Out:
# Collecting pymc
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\NRCA\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"'; __file__='"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\NRCA\AppData\Local\Temp\pip-wheel-ycpvgom2'
#        cwd: C:\Users\NRCA\AppData\Local\Temp\pip-install-tg6ksu7f\pymc\
#   Complete output (184 lines):
#   Could not locate executable g77
#   Could not locate executable f77
#   Could not locate executable ifort
#   Could not locate executable ifl
#   Could not locate executable f90
#   Could not locate executable DF
#   Could not locate executable efl
#   Could not locate executable gfortran
#   Could not locate executable f95
#   Could not locate executable g95
#   Could not locate executable efort
#   Could not locate executable efc
#   Could not locate executable flang
#   don't know how to compile Fortran code on platform 'nt'
#   C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:1730: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     return getattr(self, '_calc_info_{}'.format(name))()
#   C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:1730: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     return getattr(self, '_calc_info_{}'.format(name))()
#   C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:471: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     return cl().get_info(notfound_action)
#   No optimized BLAS or Lapack libraries found, building from source. This may take a while...
#   No optimized BLAS or Lapack libraries found, building from source. This may take a while...
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building extension "pymc.flib" sources
#   f2py options: []
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\fortranobject.c' to sources.
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc' to include_dirs.
#     adding 'build\src.win32-3.7\pymc\flib-f2pywrappers.f' to sources.
#   building extension "pymc.LazyFunction" sources
#   building extension "pymc.Container_values" sources
#   building extension "pymc.gp.linalg_utils" sources
#   f2py options: []
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\fortranobject.c' to sources.
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp' to include_dirs.
#     adding 'build\src.win32-3.7\pymc\gp\linalg_utils-f2pywrappers.f' to sources.
#   building extension "pymc.gp.incomplete_chol" sources
#   f2py options: []
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\fortranobject.c' to sources.
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp' to include_dirs.
#     adding 'build\src.win32-3.7\pymc\gp\incomplete_chol-f2pywrappers.f' to sources.
#   building extension "pymc.gp.cov_funs.isotropic_cov_funs" sources
#   f2py options: []
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs\fortranobject.c' to sources.
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs' to include_dirs.
#     adding 'build\src.win32-3.7\pymc\gp\cov_funs\isotropic_cov_funs-f2pywrappers.f' to sources.
#   building extension "pymc.gp.cov_funs.distances" sources
#   f2py options: []
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs\fortranobject.c' to sources.
#     adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs' to include_dirs.
#   build_src: building npy-pkg config files
#   running build_py
#   creating build\lib.win32-3.7
#   creating build\lib.win32-3.7\pymc
#   copying pymc\calc_utils.py -> build\lib.win32-3.7\pymc
#   copying pymc\CircularStochastic.py -> build\lib.win32-3.7\pymc
#   copying pymc\CommonDeterministics.py -> build\lib.win32-3.7\pymc
#   copying pymc\Container.py -> build\lib.win32-3.7\pymc
#   copying pymc\datatypes.py -> build\lib.win32-3.7\pymc
#   copying pymc\decorators.py -> build\lib.win32-3.7\pymc
#   copying pymc\diagnostics.py -> build\lib.win32-3.7\pymc
#   copying pymc\distributions.py -> build\lib.win32-3.7\pymc
#   copying pymc\graph.py -> build\lib.win32-3.7\pymc
#   copying pymc\InstantiationDecorators.py -> build\lib.win32-3.7\pymc
#   copying pymc\Matplot.py -> build\lib.win32-3.7\pymc
#   copying pymc\MCMC.py -> build\lib.win32-3.7\pymc
#   copying pymc\Model.py -> build\lib.win32-3.7\pymc
#   copying pymc\Node.py -> build\lib.win32-3.7\pymc
#   copying pymc\NormalApproximation.py -> build\lib.win32-3.7\pymc
#   copying pymc\NumpyDeterministics.py -> build\lib.win32-3.7\pymc
#   copying pymc\progressbar.py -> build\lib.win32-3.7\pymc
#   copying pymc\PyMCObjects.py -> build\lib.win32-3.7\pymc
#   copying pymc\ScipyDistributions.py -> build\lib.win32-3.7\pymc
#   copying pymc\six.py -> build\lib.win32-3.7\pymc
#   copying pymc\StepMethods.py -> build\lib.win32-3.7\pymc
#   copying pymc\threadpool.py -> build\lib.win32-3.7\pymc
#   copying pymc\utils.py -> build\lib.win32-3.7\pymc
#   copying pymc\__init__.py -> build\lib.win32-3.7\pymc
#   creating build\lib.win32-3.7\pymc\database
#   copying pymc/database\base.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\hdf5.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\hdf5ea.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\no_trace.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\pickle.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\ram.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\sqlite.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\txt.py -> build\lib.win32-3.7\pymc/database
#   copying pymc/database\__init__.py -> build\lib.win32-3.7\pymc/database
#   creating build\lib.win32-3.7\pymc\examples
#   copying pymc/examples\custom_step.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\disaster_model.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\disaster_model_gof.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\disaster_model_linear.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\disaster_model_missing.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\disaster_model_null.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\gelman_bioassay.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\melanoma.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\melanoma_data.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\weibull_fit.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\weibull_fit_gof.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\zip.py -> build\lib.win32-3.7\pymc/examples
#   copying pymc/examples\__init__.py -> build\lib.win32-3.7\pymc/examples
#   creating build\lib.win32-3.7\pymc\examples\gp
#   copying pymc/examples/gp\basiscov.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\cov.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\covparams.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\MCMC.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\mean.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\mesh_choice.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\observation.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\PyMCmodel.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\realizations.py -> build\lib.win32-3.7\pymc/examples/gp
#   copying pymc/examples/gp\__init__.py -> build\lib.win32-3.7\pymc/examples/gp
#   creating build\lib.win32-3.7\pymc\tests
#   copying pymc/tests\objectmodel.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_adaptive.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_AM.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_basiscov.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_binary_step.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_container.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_convergence.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_cov.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_database.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_distributions.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_GP_MCMC.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_gradients.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_graph.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_instantiation.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_interactive.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_MCMCSampler.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_mean.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_missing.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_norm_approx.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_observation.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_realization.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_slice.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_special_methods.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\test_utils.py -> build\lib.win32-3.7\pymc/tests
#   copying pymc/tests\__init__.py -> build\lib.win32-3.7\pymc/tests
#   creating build\lib.win32-3.7\pymc\gp
#   copying pymc/gp\BasisCovariance.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\Covariance.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\FullRankCovariance.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\gpplots.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\GPutils.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\gp_submodel.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\Mean.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\NearlyFullRankCovariance.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\Realization.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\step_methods.py -> build\lib.win32-3.7\pymc/gp
#   copying pymc/gp\__init__.py -> build\lib.win32-3.7\pymc/gp
#   creating build\lib.win32-3.7\pymc\gp\cov_funs
#   copying pymc/gp/cov_funs\bases.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   copying pymc/gp/cov_funs\brownian.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   copying pymc/gp/cov_funs\cov_utils.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   copying pymc/gp/cov_funs\nsmatern.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   copying pymc/gp/cov_funs\wrapped_distances.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   copying pymc/gp/cov_funs\__init__.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#   running build_ext
#   No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   customize MSVCCompiler
#   customize MSVCCompiler using build_ext
#   warning: build_ext: f77_compiler=None is not available.
#
#   building 'pymc.flib' extension
#   error: extension 'pymc.flib' has Fortran sources but no Fortran compiler found
#   ----------------------------------------
#   ERROR: Failed building wheel for pymc
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\NRCA\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"'; __file__='"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\NRCA\AppData\Local\Temp\pip-record-07sd4p50\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\NRCA\anaconda3\Include\pymc'
#          cwd: C:\Users\NRCA\AppData\Local\Temp\pip-install-tg6ksu7f\pymc\
#     Complete output (184 lines):
#     Could not locate executable g77
#     Could not locate executable f77
#     Could not locate executable ifort
#     Could not locate executable ifl
#     Could not locate executable f90
#     Could not locate executable DF
#     Could not locate executable efl
#     Could not locate executable gfortran
#     Could not locate executable f95
#     Could not locate executable g95
#     Could not locate executable efort
#     Could not locate executable efc
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#     C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:1730: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       return getattr(self, '_calc_info_{}'.format(name))()
#     C:\Users\NRCA\anaconda3\lib\site-packages\numpy\distutils\system_info.py:471: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       return cl().get_info(notfound_action)
#     No optimized BLAS or Lapack libraries found, building from source. This may take a while...
#     No optimized BLAS or Lapack libraries found, building from source. This may take a while...
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building extension "pymc.flib" sources
#     f2py options: []
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\fortranobject.c' to sources.
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc' to include_dirs.
#       adding 'build\src.win32-3.7\pymc\flib-f2pywrappers.f' to sources.
#     building extension "pymc.LazyFunction" sources
#     building extension "pymc.Container_values" sources
#     building extension "pymc.gp.linalg_utils" sources
#     f2py options: []
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\fortranobject.c' to sources.
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp' to include_dirs.
#       adding 'build\src.win32-3.7\pymc\gp\linalg_utils-f2pywrappers.f' to sources.
#     building extension "pymc.gp.incomplete_chol" sources
#     f2py options: []
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\fortranobject.c' to sources.
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp' to include_dirs.
#       adding 'build\src.win32-3.7\pymc\gp\incomplete_chol-f2pywrappers.f' to sources.
#     building extension "pymc.gp.cov_funs.isotropic_cov_funs" sources
#     f2py options: []
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs\fortranobject.c' to sources.
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs' to include_dirs.
#       adding 'build\src.win32-3.7\pymc\gp\cov_funs\isotropic_cov_funs-f2pywrappers.f' to sources.
#     building extension "pymc.gp.cov_funs.distances" sources
#     f2py options: []
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs\fortranobject.c' to sources.
#       adding 'build\src.win32-3.7\build\src.win32-3.7\pymc\gp\cov_funs' to include_dirs.
#     build_src: building npy-pkg config files
#     running build_py
#     creating build\lib.win32-3.7
#     creating build\lib.win32-3.7\pymc
#     copying pymc\calc_utils.py -> build\lib.win32-3.7\pymc
#     copying pymc\CircularStochastic.py -> build\lib.win32-3.7\pymc
#     copying pymc\CommonDeterministics.py -> build\lib.win32-3.7\pymc
#     copying pymc\Container.py -> build\lib.win32-3.7\pymc
#     copying pymc\datatypes.py -> build\lib.win32-3.7\pymc
#     copying pymc\decorators.py -> build\lib.win32-3.7\pymc
#     copying pymc\diagnostics.py -> build\lib.win32-3.7\pymc
#     copying pymc\distributions.py -> build\lib.win32-3.7\pymc
#     copying pymc\graph.py -> build\lib.win32-3.7\pymc
#     copying pymc\InstantiationDecorators.py -> build\lib.win32-3.7\pymc
#     copying pymc\Matplot.py -> build\lib.win32-3.7\pymc
#     copying pymc\MCMC.py -> build\lib.win32-3.7\pymc
#     copying pymc\Model.py -> build\lib.win32-3.7\pymc
#     copying pymc\Node.py -> build\lib.win32-3.7\pymc
#     copying pymc\NormalApproximation.py -> build\lib.win32-3.7\pymc
#     copying pymc\NumpyDeterministics.py -> build\lib.win32-3.7\pymc
#     copying pymc\progressbar.py -> build\lib.win32-3.7\pymc
#     copying pymc\PyMCObjects.py -> build\lib.win32-3.7\pymc
#     copying pymc\ScipyDistributions.py -> build\lib.win32-3.7\pymc
#     copying pymc\six.py -> build\lib.win32-3.7\pymc
#     copying pymc\StepMethods.py -> build\lib.win32-3.7\pymc
#     copying pymc\threadpool.py -> build\lib.win32-3.7\pymc
#     copying pymc\utils.py -> build\lib.win32-3.7\pymc
#     copying pymc\__init__.py -> build\lib.win32-3.7\pymc
#     creating build\lib.win32-3.7\pymc\database
#     copying pymc/database\base.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\hdf5.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\hdf5ea.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\no_trace.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\pickle.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\ram.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\sqlite.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\txt.py -> build\lib.win32-3.7\pymc/database
#     copying pymc/database\__init__.py -> build\lib.win32-3.7\pymc/database
#     creating build\lib.win32-3.7\pymc\examples
#     copying pymc/examples\custom_step.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\disaster_model.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\disaster_model_gof.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\disaster_model_linear.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\disaster_model_missing.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\disaster_model_null.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\gelman_bioassay.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\melanoma.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\melanoma_data.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\weibull_fit.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\weibull_fit_gof.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\zip.py -> build\lib.win32-3.7\pymc/examples
#     copying pymc/examples\__init__.py -> build\lib.win32-3.7\pymc/examples
#     creating build\lib.win32-3.7\pymc\examples\gp
#     copying pymc/examples/gp\basiscov.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\cov.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\covparams.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\MCMC.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\mean.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\mesh_choice.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\observation.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\PyMCmodel.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\realizations.py -> build\lib.win32-3.7\pymc/examples/gp
#     copying pymc/examples/gp\__init__.py -> build\lib.win32-3.7\pymc/examples/gp
#     creating build\lib.win32-3.7\pymc\tests
#     copying pymc/tests\objectmodel.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_adaptive.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_AM.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_basiscov.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_binary_step.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_container.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_convergence.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_cov.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_database.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_distributions.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_GP_MCMC.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_gradients.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_graph.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_instantiation.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_interactive.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_MCMCSampler.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_mean.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_missing.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_norm_approx.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_observation.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_realization.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_slice.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_special_methods.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\test_utils.py -> build\lib.win32-3.7\pymc/tests
#     copying pymc/tests\__init__.py -> build\lib.win32-3.7\pymc/tests
#     creating build\lib.win32-3.7\pymc\gp
#     copying pymc/gp\BasisCovariance.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\Covariance.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\FullRankCovariance.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\gpplots.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\GPutils.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\gp_submodel.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\Mean.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\NearlyFullRankCovariance.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\Realization.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\step_methods.py -> build\lib.win32-3.7\pymc/gp
#     copying pymc/gp\__init__.py -> build\lib.win32-3.7\pymc/gp
#     creating build\lib.win32-3.7\pymc\gp\cov_funs
#     copying pymc/gp/cov_funs\bases.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     copying pymc/gp/cov_funs\brownian.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     copying pymc/gp/cov_funs\cov_utils.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     copying pymc/gp/cov_funs\nsmatern.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     copying pymc/gp/cov_funs\wrapped_distances.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     copying pymc/gp/cov_funs\__init__.py -> build\lib.win32-3.7\pymc/gp/cov_funs
#     running build_ext
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     customize MSVCCompiler using build_ext
#     warning: build_ext: f77_compiler=None is not available.
#
#     building 'pymc.flib' extension
#     error: extension 'pymc.flib' has Fortran sources but no Fortran compiler found
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\NRCA\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"'; __file__='"'"'C:\\Users\\NRCA\\AppData\\Local\\Temp\\pip-install-tg6ksu7f\\pymc\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\NRCA\AppData\Local\Temp\pip-record-07sd4p50\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\NRCA\anaconda3\Include\pymc' Check the logs for full command output.
#   Downloading pymc-2.3.8.tar.gz (385 kB)
# Building wheels for collected packages: pymc
#   Building wheel for pymc (setup.py): started
#   Building wheel for pymc (setup.py): finished with status 'error'
#   Running setup.py clean for pymc
# Failed to build pymc
# Installing collected packages: pymc
#     Running setup.py install for pymc: started
#     Running setup.py install for pymc: finished with status 'error'

# %%
# For estimating theta, we shall first generate 30 samples from the Bernoulli distribution, 
# where the controlling parameter has a value of 0.3 
# (which would correspond to roughly 30% of the generated values being 1, and the rest being 0).

# Importing the libraries we will need
from pymc3 import *
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
import pymc3.Matplot as plott
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\NRCA\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-51c5b89207c3> in <module>
#       7 from scipy.stats import bernoulli
#       8 import matplotlib.pyplot as plt
# ----> 9 import pymc3.Matplot as plott
#
# ModuleNotFoundError: No module named 'pymc3.Matplot'

# %%
# We attempt to find the parameters of the posterior distribution, and we've learnt that the 
#posterior depends on the prior, as well the data. 
# There are many choices of prior available to us, in this case we shall use the uniform prior. 
# Since we have little idea about the bias of the thumbtack, we believe it can lie anywhere
#between 0 and 1.
# The PyMC model contains two variables. The first is a Uniform prior, which represents our belief 
# that the value of the parameter can be anywhere between 0 and 1. 
# The second is the Bernoulli variable, to which we provide data. The two variables are linked in
#a parent-child relationship, 
# the Uniform prior is the designated parent of the Bernoulli variable.
# We use two types of PyMC variables: Stochastic (the uni_prior variable, which can take different
#values based on the parameter theta). 
# Deterministic (such as 'bern', whose values are decided by its parents). Finally, all the 
#variables in the model are wrapped in a Model object.
# For all variables where observed is not True, PyMC's simulations will tickle the value of 
#the variable during the simulation 
# and the value (of uni_prior in our case) will start to approximate its posterior values.

from pymc import *
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
import pymc.Matplot as plott

# Samples drawn from the prior distribution show that the prior is uniformly distributed between 0 and 1 on the x axis.
def create_model(data):
    #create a uniform prior, the lower and upper limits of which are 0 and 1
    uni_prior = Uniform('uni_prior', lower=0,upper=1.0 )
    bern = Bernoulli('bern',p=uni_prior, value=data,observed=True)
    model=Model([uni_prior,bern])
    return model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-384e44180d97> in <module>
#      17 # and the value (of uni_prior in our case) will start to approximate its posterior values.
#      18
# ---> 19 from pymc import *
#      20 from scipy.stats import bernoulli
#      21 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pymc'

# %%
# We now use a sampling method called Markov Chain Monte Carlo (hence the acronym MCMC). 
# MCMC is one of the methods used to draw samples from the posterior distribution. 
# We draw 5k samples, and draw a histogram of the samples (called traces in MCMC parlance).
# In Bayesian statistics, the parameter theta is represented as a random variable and not a single value.

sample_size=30

def get_traces(sample_size):
    data=bernoulli.rvs(0.3,size=sample_size)
    model=create_model(data)
    model.seed()
    mc1 = MCMC(model)
    mc1.sample(iter=5000,burn=1000)
    return mc1,mc1.trace('uni_prior')[:]

mc1,traces=get_traces(sample_size)
plott.histogram(traces,"uni_prior")


# We plot the posterior distribution of the parameter theta. We can see that the distribution has quite a bit of variance, 
# and the peak of the distribution (indicated by a black vertical line) 
# does not correspond to 0.3 (which is the true value of the parameter theta). 
# The peak of the distribution hill is called a point estimate in Bayesian parlance, 
# which is analogous to the "best estimate" if we want to represent the parameter theta as a single value.

# %%
# We then plot the posterior distribution for an increasing number of samples.
num_samples=[20,50,100,500,5000]
for i in num_samples:
    m,traces=get_traces(i)
    plott.histogram(traces,"num samples = "+str(i),datarange=(0,0.6))
    
# We can see that increasing the number of samples makes the distribution "hill" sharper, 
# which indicates its growing confidence in its estimate of the parameter theta.

# %%
# Example 2
# ---
# I tossed my coin 30  times, and it came up as heads  11  times. Is it biased?
# ---
# 

# Parameterized problem:
#
# "I want to know  p , the probability of tossing heads. Given  n  tosses and  h  observed heads, 
# is it probable that the value of  p  is close to  0.5  , say, in the interval  [0.48,0.52] ?"

# Prior:
# prior belief about parameter:  p∼Uniform(0,1) 
# likelihood function:  data∼Bernoulli(p)

# %%
# Make the data needed for the problem.
from random import shuffle
total = 30
n_heads = 11
n_tails = total - n_heads
tosses = [1] * n_heads + [0] * n_tails
shuffle(tosses)

# printing out data
print(tosses)

# %%
# Creating a function to plot our tosses
def plot_coins():
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    ax.bar(list(Counter(tosses).keys()), list(Counter(tosses).values()))
    ax.set_xticks([0, 1])
    ax.set_xticklabels(['tails', 'heads'])
    ax.set_ylim(0, 20)
    ax.set_yticks(np.arange(0, 21, 5))
    return fig

# %%
# Plotting
fig = plot_coins()
plt.show()

# %%
# Context manager syntax. `coin_model` is **just** 
# a placeholder
# 
with pm.Model() as coin_model: 
    # Distributions are PyMC3 objects.
    # Specify prior using Uniform object.
    p_prior = pm.Uniform('p', 0, 1)  
    
    # Specify likelihood using Bernoulli object.
    like = pm.Bernoulli('likelihood', p=p_prior, 
                        observed=tosses)  
                        # "observed=data" is key
                        # for likelihood.

# %%
# Writing our model in PyMC3, hitting the MCMC Inference Button (TM)
# 
with coin_model:
    # don't worry about this:
    step = pm.Metropolis()
    
    # focus on this, the Inference Button:
    coin_trace = pm.sample(2000, step=step)

# %%
# Results
# 
pm.traceplot(coin_trace)
plt.show()

# %%
# Interpreting based on posterior distributions
# 
pm.plot_posterior(coin_trace[100:], color='#87ceeb', 
                  rope=[0.48, 0.52], point_estimate='mean', 
                  ref_val=0.5)
plt.show()

# 95% highest posterior density (HPD) encompasses the region of practical equivalence (ROPE) 
# thus we need to get more data. For more info (http://bit.ly/HPDandROPE)

# %% [markdown]
# ## <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# I tossed my coin 50  times, and it came up as tails 29  times. Is it biased?
# --
# 
OUR CODE GOES HERE

# %%
# Challenge 2
# ---
# Assume that we run an website for selling safari shoes and in order to bring people to our site, 
# we deploy several digital marketing campaigns. 
# These campaigns feature various ad images and captions, and are presented on a number of social networking websites. 
# We want to present the ads that are the most successful. 
# For the sake of simplicity, we can assume that the most successful campaign 
# is the one that results in the highest click-through rate: the ads that are most likely to be clicked if shown.
# We introduce a new campaign called "facebook-yellow-dress," a campaign presented to Facebook users featuring a yellow dress. 
# The ad has been presented to 10 users so far, and 7 of the users have clicked on it. 
# Determine the probability that the next user will click on the ad.
# --
OUR CODE GOES HERE
