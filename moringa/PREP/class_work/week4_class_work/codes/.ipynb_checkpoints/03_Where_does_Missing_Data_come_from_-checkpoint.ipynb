# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Where does Missing Data come from?

# %% [markdown]
# In the course of your data science career,  it is rare that you will work with raw data that does not have missing values.
#
# Missing data can arise from the loading of data, when merging data, data entry or the reindexing process - the process of transforming data from one process to the other. We will see how this can happen in the sections below:

# %% [markdown]
# ## 1.0 Loading Data

# %% [markdown]
# When we load data with pandas, we get a dataframe with the NaN value in the cell that had missing data. This is as a result of the read_csv function, which can take the following parameters which relate to reading in missing values: na_values, keep_default_na and na_filter.
#
# We will now see how these parameters work.

# %%
# First lets import our dataset that we will use for the examples

# Let's import our pandas library 
import pandas as pd

# Let's set the location for our data
url = 'http://bit.ly/UniversityDataSet'

# We then store this dataset in a dataframe
# We us the latin1 encoding because our dataset contains special characters. 
# An encoding is one specific way of interpreting bytes: It's a look-up table that says, 
# for example, that a byte with the value 97 stands for 'a'.
#
df = pd.read_csv(url, encoding = "latin1")

# then view the columns of this dataframe, this will help us get familiar with the dataset before working on it
df.columns.values.tolist()
# Out:
# ['Year',
#  'Org Name',
#  'Org Code',
#  'Spec Ed. Grad Rate - Grad Cohort #',
#  'Spec Ed. Grad Rate - Grad #',
#  'Spec Ed. Grad Rate - Grad %',
#  'Spec Ed. Dropout - Enr #',
#  'Spec Ed. Dropout - Drop #',
#  'Spec Ed. Dropout - Drop %',
#  'LRE Ages 6-21 - Students #',
#  'LRE Ages 6-21 - Full Incl #',
#  'LRE Ages 6-21 - Full Incl %',
#  'LRE Ages 3-5 - Students #',
#  'LRE Ages 3-5 - Full Incl #',
#  'LRE Ages 3-5 - Full Incl %',
#  'Cohort Completion Year',
#  'Substantial growth of knowledge & skills',
#  'Survey Period',
#  'Surv Meet Std #',
#  'Surv Meet Std %',
#  'Sch Yr Rev',
#  '# of Students Engaged',
#  'Dist Rate']

# %%
# We will then load the first 5 rows of our data and try to understand it more, while noting the missing values in the records, 
# afterwards learn more about the parameters
# 
df.head()
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000                                NaN
# 3  2013     Acton     20000                                NaN
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2                      NaN                       NaN
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop %  LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                       295.0  ...
# 1                     2.90%                       272.0  ...
# 2                       NaN                       337.0  ...
# 3                         -                       335.0  ...
# 4                         -                       174.0  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013             NaN             NaN    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# **i) na_values**
#
# The na_values parameter will allow us to specify additional missing or NaN values. What are NaN values you ask?
#
# > *These NaN values are from the python numpy library - Missing values in python are displayed in a few ways - NaN, NAN or nan and are all equivalent.*
#
# By default, this parameter is usually never used when reading the file mainly because these default missing values - NaN or nan, are already available.

# %%
# now we load the data with the default values
print(pd.read_csv(url, encoding = 'latin1').head())
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000                                NaN
# 3  2013     Acton     20000                                NaN
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2                      NaN                       NaN
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop %  LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                       295.0  ...
# 1                     2.90%                       272.0  ...
# 2                       NaN                       337.0  ...
# 3                         -                       335.0  ...
# 4                         -                       174.0  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013             NaN             NaN    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# **ii) keep_default_na**
#
# The second parameter is the `keep_default_na` parameter, which is a bool (boolean). It allows us to specify whether any additional values need to be considered missing. By default this parameter is True, meaning any additional missing values specified with the na_values paramenter will be appended to list of missing values.
#
# We can also set `keep_default_na=False` which will mean that we will only use missing values specified in na_values.

# %%
# Example 2
# We then load the data without default missing values 
# 
print(pd.read_csv(url, encoding = 'latin1', keep_default_na = False).head())
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000
# 3  2013     Acton     20000
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2
# 3
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop % LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                        295  ...
# 1                     2.90%                        272  ...
# 2                                                  337  ...
# 3                         -                        335  ...
# 4                         -                        174  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013                                    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4
#
# [5 rows x 23 columns]

# %%
# Challenge 1: 
# Using the keep_default_na parameter, load the data with the default missing values below
# 
print(pd.read_csv(url, encoding = 'latin1', keep_default_na = True).head())
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000                                NaN
# 3  2013     Acton     20000                                NaN
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2                      NaN                       NaN
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop %  LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                       295.0  ...
# 1                     2.90%                       272.0  ...
# 2                       NaN                       337.0  ...
# 3                         -                       335.0  ...
# 4                         -                       174.0  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013             NaN             NaN    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# iii) **na_filter**
#
# Our third parameter is the *na_filter parameter,* which is a bool that specifies whether any values will be read as missing. By default the na_filter=True, meaning that missing values will be coded as NaN. If na_filter=False, then nothing will be recorded as missing. We normally use this parameter when we want to set false the na_values and keep_default_na parameter all at the same time as well as when we want to quickly load any data without missing values.

# %%
# Example 3
# Let's set the na_filter parameter to True
# 
print(pd.read_csv(url, na_filter = True, encoding ='latin1').head())
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000                                NaN
# 3  2013     Acton     20000                                NaN
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2                      NaN                       NaN
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop %  LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                       295.0  ...
# 1                     2.90%                       272.0  ...
# 2                       NaN                       337.0  ...
# 3                         -                       335.0  ...
# 4                         -                       174.0  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013             NaN             NaN    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4                   NaN
#
# [5 rows x 23 columns]

# %%
# Challenge 2
# Now let's see what happens when we set the na_filter parameter to False
# 
print(pd.read_csv(url, na_filter = False, encoding ='latin1').head())
# Out:
#    Year  Org Name  Org Code Spec Ed. Grad Rate - Grad Cohort #  \
# 0  2012  Abington     10000                                 27
# 1  2013  Abington     10000                                 20
# 2  2012     Acton     20000
# 3  2013     Acton     20000
# 4  2012  Acushnet     30000                                  3
#
#   Spec Ed. Grad Rate - Grad # Spec Ed. Grad Rate - Grad %  \
# 0                          17                         63%
# 1                          16                         80%
# 2
# 3
# 4                           -                           -
#
#   Spec Ed. Dropout - Enr # Spec Ed. Dropout - Drop #  \
# 0                       84                         3
# 1                       70                         2
# 2
# 3                        0                         -
# 4                        0                         -
#
#   Spec Ed. Dropout - Drop % LRE Ages 6-21 - Students #  ...  \
# 0                     3.60%                        295  ...
# 1                     2.90%                        272  ...
# 2                                                  337  ...
# 3                         -                        335  ...
# 4                         -                        174  ...
#
#   LRE Ages 3-5 - Full Incl # LRE Ages 3-5 - Full Incl %  \
# 0                          1                         5%
# 1                          4                        19%
# 2                          6                     10.30%
# 3                         16                     26.70%
# 4                          7                        25%
#
#   Cohort Completion Year Substantial growth of knowledge & skills  \
# 0                2012-13                                        -
# 1                2012-13                                        -
# 2                2010-11                                     86.7
# 3                2010-11                                     86.7
# 4                2013-14                                        -
#
#   Survey Period Surv Meet Std # Surv Meet Std % Sch Yr Rev  \
# 0   Spring 2013                                    2010-11
# 1   Spring 2013              11          73.20%    2010-11
# 2   Spring 2011               -               -    2012-13
# 3   Spring 2011               -               -    2012-13
# 4   Spring 2012               -               -    2011-12
#
#   # of Students Engaged Dist Rate
# 0                     8      100%
# 1                     8      100%
# 2                    NR        NR
# 3                    NR        NR
# 4
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 1.1 Merging Data

# %% [markdown]
# Missing data can also result from the merging of datasets. This we will see when we create a merged table from the two datasets below.
#
# Having missing values in the merged table can be as a result of either or neither of the datasets having any missing values i.e. if the datasets have unique columns.

# %%
apple_orange_dataset = 'http://bit.ly/AppleOrangeDataSet'
stability_dataset    = 'http://bit.ly/StabilityDataset'

apple_orange_dataset = pd.read_csv(apple_orange_dataset, encoding ='latin1')
stability_dataset    = pd.read_csv(stability_dataset, encoding ='latin1')

# %% [markdown]
# The appleorange dataset  contains production volumes of apples and oranges while the stability dataset contains country stability indicators.

# %%
# Displaying our the first dataset
#
apple_orange_dataset.head(10)
# Out:
#                              FAOSTAT 2013 Unnamed: 1  \
# 0                              Elements Ê        NaN
# 1  Food supply quantity (tonnes) (tonnes)        NaN
# 2  Food supply quantity (tonnes) (tonnes)        NaN
# 3  Food supply quantity (tonnes) (tonnes)        NaN
# 4                                 Albania          3
# 5  Food supply quantity (tonnes) (tonnes)        NaN
# 6                                 Albania          3
# 7  Food supply quantity (tonnes) (tonnes)        NaN
# 8                                 Algeria          4
# 9  Food supply quantity (tonnes) (tonnes)        NaN
#
#                                Unnamed: 2  Unnamed: 3             Unnamed: 4  \
# 0                                 Areas Ê         NaN                Items Ê
# 1                                     NaN         NaN                    NaN
# 2  Food supply quantity (tonnes) (tonnes)         NaN                    NaN
# 3                                     NaN         NaN                    NaN
# 4                     Apples and products      2617.0   57Ê459.00, tonnes ()
# 5                                     NaN         NaN                    NaN
# 6                     Oranges, Mandarines      2611.0   40Ê880.00, tonnes ()
# 7                                     NaN         NaN                    NaN
# 8                     Apples and products      2617.0  370Ê008.00, tonnes ()
# 9                                     NaN         NaN                    NaN
#
#    Unnamed: 5
# 0      2009.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %%
# Displaying our second dataset
# 
stability_dataset.head(10)
# Out:
#     FAOSTAT 2013 Unnamed: 1  \
# 0     Elements Ê        NaN
# 1  Value (index)        NaN
# 2  Value (index)        NaN
# 3  Value (index)        NaN
# 4    Afghanistan          2
# 5  Value (index)        NaN
# 6        Albania          3
# 7  Value (index)        NaN
# 8        Algeria          4
# 9  Value (index)        NaN
#
#                                           Unnamed: 2  Unnamed: 3  \
# 0                                            Areas Ê         NaN
# 1                                                NaN         NaN
# 2                                      Value (index)         NaN
# 3                                                NaN         NaN
# 4  Political stability and absence of violence/te...     21032.0
# 5                                                NaN         NaN
# 6  Political stability and absence of violence/te...     21032.0
# 7                                                NaN         NaN
# 8  Political stability and absence of violence/te...     21032.0
# 9                                                NaN         NaN
#
#         Unnamed: 4  Unnamed: 5
# 0          Items Ê      2009.0
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4  -2.70, index ()         NaN
# 5              NaN         NaN
# 6  -0.05, index ()         NaN
# 7              NaN         NaN
# 8  -1.23, index ()         NaN
# 9              NaN         NaN

# %%
# Now merging the two dataframes and analysing the output
merged_dataset = apple_orange_dataset.merge(stability_dataset, left_on='FAOSTAT 2013', right_on='FAOSTAT 2013')

# Displayig our dataset
merged_dataset.head(20)
# Out:
#            FAOSTAT 2013 Unnamed: 1_x         Unnamed: 2_x  Unnamed: 3_x  \
# 0            Elements Ê          NaN              Areas Ê           NaN
# 1               Albania            3  Apples and products        2617.0
# 2               Albania            3  Apples and products        2617.0
# 3               Albania            3  Apples and products        2617.0
# 4               Albania            3  Oranges, Mandarines        2611.0
# 5               Albania            3  Oranges, Mandarines        2611.0
# 6               Albania            3  Oranges, Mandarines        2611.0
# 7               Algeria            4  Apples and products        2617.0
# 8               Algeria            4  Apples and products        2617.0
# 9               Algeria            4  Apples and products        2617.0
# 10              Algeria            4  Oranges, Mandarines        2611.0
# 11              Algeria            4  Oranges, Mandarines        2611.0
# 12              Algeria            4  Oranges, Mandarines        2611.0
# 13               Angola            7  Apples and products        2617.0
# 14               Angola            7  Apples and products        2617.0
# 15               Angola            7  Oranges, Mandarines        2611.0
# 16               Angola            7  Oranges, Mandarines        2611.0
# 17  Antigua and Barbuda            8  Apples and products        2617.0
# 18  Antigua and Barbuda            8  Apples and products        2617.0
# 19  Antigua and Barbuda            8  Oranges, Mandarines        2611.0
#
#              Unnamed: 4_x  Unnamed: 5_x Unnamed: 1_y  \
# 0                 Items Ê        2009.0          NaN
# 1    57Ê459.00, tonnes ()           NaN            3
# 2    57Ê459.00, tonnes ()           NaN            3
# 3    57Ê459.00, tonnes ()           NaN            3
# 4    40Ê880.00, tonnes ()           NaN            3
# 5    40Ê880.00, tonnes ()           NaN            3
# 6    40Ê880.00, tonnes ()           NaN            3
# 7   370Ê008.00, tonnes ()           NaN            4
# 8   370Ê008.00, tonnes ()           NaN            4
# 9   370Ê008.00, tonnes ()           NaN            4
# 10  762Ê365.00, tonnes ()           NaN            4
# 11  762Ê365.00, tonnes ()           NaN            4
# 12  762Ê365.00, tonnes ()           NaN            4
# 13    4Ê481.00, tonnes ()           NaN            7
# 14    4Ê481.00, tonnes ()           NaN            7
# 15      978.00, tonnes ()           NaN            7
# 16      978.00, tonnes ()           NaN            7
# 17      722.00, tonnes ()           NaN            8
# 18      722.00, tonnes ()           NaN            8
# 19    3Ê521.00, tonnes ()           NaN            8
#
#                                          Unnamed: 2_y  Unnamed: 3_y  \
# 0                                             Areas Ê           NaN
# 1   Political stability and absence of violence/te...       21032.0
# 2   Per capita food supply variability (kcal/capit...       21031.0
# 3   Rail-lines density (per 100 square km of land ...       21016.0
# 4   Political stability and absence of violence/te...       21032.0
# 5   Per capita food supply variability (kcal/capit...       21031.0
# 6   Rail-lines density (per 100 square km of land ...       21016.0
# 7   Political stability and absence of violence/te...       21032.0
# 8   Per capita food supply variability (kcal/capit...       21031.0
# 9   Rail-lines density (per 100 square km of land ...       21016.0
# 10  Political stability and absence of violence/te...       21032.0
# 11  Per capita food supply variability (kcal/capit...       21031.0
# 12  Rail-lines density (per 100 square km of land ...       21016.0
# 13  Political stability and absence of violence/te...       21032.0
# 14  Per capita food supply variability (kcal/capit...       21031.0
# 15  Political stability and absence of violence/te...       21032.0
# 16  Per capita food supply variability (kcal/capit...       21031.0
# 17  Political stability and absence of violence/te...       21032.0
# 18  Per capita food supply variability (kcal/capit...       21031.0
# 19  Political stability and absence of violence/te...       21032.0
#
#                                Unnamed: 4_y  Unnamed: 5_y
# 0                                   Items Ê        2009.0
# 1                           -0.05, index ()           NaN
# 2                 40.29, kcal/capita/day ()           NaN
# 3   1.47, per 100 square km of land area ()           NaN
# 4                           -0.05, index ()           NaN
# 5                 40.29, kcal/capita/day ()           NaN
# 6   1.47, per 100 square km of land area ()           NaN
# 7                           -1.23, index ()           NaN
# 8                 27.94, kcal/capita/day ()           NaN
# 9   0.20, per 100 square km of land area ()           NaN
# 10                          -1.23, index ()           NaN
# 11                27.94, kcal/capita/day ()           NaN
# 12  0.20, per 100 square km of land area ()           NaN
# 13                          -0.32, index ()           NaN
# 14                26.81, kcal/capita/day ()           NaN
# 15                          -0.32, index ()           NaN
# 16                26.81, kcal/capita/day ()           NaN
# 17                           0.75, index ()           NaN
# 18                52.10, kcal/capita/day ()           NaN
# 19                           0.75, index ()           NaN

# %%
# Challenge 4:
# Merge the following two manifesto project datasets and 
# discuss with your peer on origin of the missing values in the merged dataset
#
party_names_dataset  = 'http://bit.ly/PartyNamesMarporDataSet'
party_names_dataset2 = 'http://bit.ly/PartyNamesPledges'

df1 = pd.read_csv(party_names_dataset, encoding="Latin1")
df2 = pd.read_csv(party_names_dataset2, encoding="Latin1")

merged = df1.merge(df2, left_on=' name', right_on=' name')
merged
# Out:
#        name             c_p  partyid
# 0      US_R    US_Democrats      101
# 1      US_D  US_Republicans      102
# 2   NL_PvdA         NL_PvdA        5
# 3    NL_D66          NL_D66        6
# 4    NL_CDA          NL_CDA        7
# ..      ...             ...      ...
# 60   CA_Con           CA_CP     1103
# 61   CA_Lib           CA_LP     1104
# 62   CA_NDP          CA_NDP     1105
# 63   CA_PCP          CA_PCP     1106
# 64   CA_RPC          CA_RPC     1107
#
# [65 rows x 3 columns]

# %% [markdown]
# ## 1.2 User Input Values

# %% [markdown]
# Missing values within a dataset can also result from mistakes from the user during the data entry/collection phase. This could also result from creating a vector of values from a calculation or from manually curating a vector as shown in the examples below.

# %%
# Importing nan from numpy so as to represent missing values
#
from numpy import nan

# %%
# Creating a missing value in a series
# NB: Series is the datastructure for a single column of a DataFrame. 
# 
population = pd.Series({'Kenya': 47, 'Tanzania': nan, 'Uganda': 30})

# Lets now print. Note that NaNs are also valid values for both Series and DataFrames
#
population
# Out:
# Kenya       47.0
# Tanzania     NaN
# Uganda      30.0
# dtype: float64

# %%
# Challenge 5:
# Create a series with the names and ages of your peers. Note nan for the ages of peers who you don't know.
# 
list_data = [['John', nan], ['Zack', 24], ['Faith', 20]]
columns = ['Name', 'Age']
frame = pd.DataFrame(list_data, columns=columns)
frame
# Out:
#     Name   Age
# 0   John   NaN
# 1   Zack  24.0
# 2  Faith  20.0

# %%
# Now creating a missing value in a dataframe
list_data = [['Steve', 56, 'Nairobi', 'no'],['Bill', 57, 'Machackos', 'yes'],['Richard', nan, nan, 'yes']]

# Defining our columns
age_df = pd.DataFrame(list_data, columns=['Name', 'Age', 'Hometown', 'Public Commute'])

# Printing age_df
age_df
# Out:
#       Name   Age   Hometown Public Commute
# 0    Steve  56.0    Nairobi             no
# 1     Bill  57.0  Machackos            yes
# 2  Richard   NaN        NaN            yes

# %%
# We can also assign a column of missing values to a dataframe directly
#
age_df['Public Commute'] = 'Yes';

# print age_df
#
age_df
# Out:
#       Name   Age   Hometown Public Commute
# 0    Steve  56.0    Nairobi            Yes
# 1     Bill  57.0  Machackos            Yes
# 2  Richard   NaN        NaN            Yes

# %%
# Challenge 6
# Create a dataframe with a list of your country's presidents 
# with their no. of years in office and their last year in office. 
# NB: You do not know the last year of office for the current president. 
#
columns = ['president', 'years in office', 'last year']
list_data = [['Kenyatta', 7, 2022], ['Mugabe', 24, nan]]
frame = pd.DataFrame(list_data, columns=columns)
frame
# Out:
#   president  years in office  last year
# 0  Kenyatta                7     2022.0
# 1    Mugabe               24        NaN

# %% [markdown]
# ## 1.3 Re-indexing

# %% [markdown]
# Missing values in data can also be introduced when we reindex our dataframe. We will show this through  a dataset from Gapminder.

# %%
# Getting our dataset
gapminder_dataset    = 'http://bit.ly/GapMinderKenyaDataSet'
gapminder_dataset_df = pd.read_csv(gapminder_dataset, encoding ='latin1')

# printing the dataframe
print(gapminder_dataset_df)
# Out:
#    country continent  year  lifeExp       pop    gdpPercap
# 0    Kenya    Africa  1952   42.270   6464046   853.540919
# 1    Kenya    Africa  1957   44.686   7454779   944.438315
# 2    Kenya    Africa  1962   47.949   8678557   896.966373
# 3    Kenya    Africa  1967   50.654  10191512  1056.736457
# 4    Kenya    Africa  1972   53.559  12044785  1222.359968
# 5    Kenya    Africa  1977   56.155  14500404  1267.613204
# 6    Kenya    Africa  1982   58.766  17661452  1348.225791
# 7    Kenya    Africa  1987   59.339  21198082  1361.936856
# 8    Kenya    Africa  1992   59.285  25020539  1341.921721
# 9    Kenya    Africa  1997   54.407  28263827  1360.485021
# 10   Kenya    Africa  2002   50.992  31386842  1287.514732
# 11   Kenya    Africa  2007   54.110  35610177  1463.249282

# %%
# now performing a groupby operation so as to subset the data
life_exp = gapminder_dataset_df.groupby(['year'])['lifeExp'].mean()
print(life_exp)
# Out:
# year
# 1952    42.270
# 1957    44.686
# 1962    47.949
# 1967    50.654
# 1972    53.559
# 1977    56.155
# 1982    58.766
# 1987    59.339
# 1992    59.285
# 1997    54.407
# 2002    50.992
# 2007    54.110
# Name: lifeExp, dtype: float64

# %%
# We then reindexing by slicing the data. We continue to chain the 'loc' from the code above
print(life_exp.loc[[range(2000, 2007)]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-90b8681e0ca4> in <module>
#       1 # We then reindexing by slicing the data. We continue to chain the 'loc' from the code above
# ----> 2 print(life_exp.loc[[range(2000, 2007)]])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index([(2000, 2001, 2002, 2003, 2004, 2005, 2006)], dtype='object', name='year')] are in the [index]"

# %% [markdown]
# Now, it seems we have been provided a suggestion to use the reindex() method. We will do this below as we choose to subset the data separately and then use the reindex() method.

# %%
# subsetting the dataframe
y_2000_df = life_exp[life_exp.index > 2000] 
print(y_2000_df)
# Out:
# year
# 2002    50.992
# 2007    54.110
# Name: lifeExp, dtype: float64

# %%
# then reindexing
print(y_2000_df.reindex(range(2000, 2010)))
# Out:
# year
# 2000       NaN
# 2001       NaN
# 2002    50.992
# 2003       NaN
# 2004       NaN
# 2005       NaN
# 2006       NaN
# 2007    54.110
# 2008       NaN
# 2009       NaN
# Name: lifeExp, dtype: float64

# %%
# Challenge 7
# We would want to look at only the years from 2000 to 2010 from the gapminder dataset below. 
# Perform grouped operations, subseting the data and then re-indexing it. 
# Show how this process might result to getting missing values.

# Assinging data the url for our dataset
data = 'http://bit.ly/GapMinderUgandaDataSet'

frame = pd.read_csv(data)
frame.index = frame['year']

mike = frame.reindex(range(1952, 2010))
mike
# Out:
#      country continent    year  lifeExp         pop    gdpPercap
# year
# 1952  Uganda    Africa  1952.0   39.978   5824797.0   734.753484
# 1953     NaN       NaN     NaN      NaN         NaN          NaN
# 1954     NaN       NaN     NaN      NaN         NaN          NaN
# 1955     NaN       NaN     NaN      NaN         NaN          NaN
# 1956     NaN       NaN     NaN      NaN         NaN          NaN
# 1957  Uganda    Africa  1957.0   42.571   6675501.0   774.371069
# 1958     NaN       NaN     NaN      NaN         NaN          NaN
# 1959     NaN       NaN     NaN      NaN         NaN          NaN
# 1960     NaN       NaN     NaN      NaN         NaN          NaN
# 1961     NaN       NaN     NaN      NaN         NaN          NaN
# 1962  Uganda    Africa  1962.0   45.344   7688797.0   767.271740
# 1963     NaN       NaN     NaN      NaN         NaN          NaN
# 1964     NaN       NaN     NaN      NaN         NaN          NaN
# 1965     NaN       NaN     NaN      NaN         NaN          NaN
# 1966     NaN       NaN     NaN      NaN         NaN          NaN
# 1967  Uganda    Africa  1967.0   48.051   8900294.0   908.918522
# 1968     NaN       NaN     NaN      NaN         NaN          NaN
# 1969     NaN       NaN     NaN      NaN         NaN          NaN
# 1970     NaN       NaN     NaN      NaN         NaN          NaN
# 1971     NaN       NaN     NaN      NaN         NaN          NaN
# 1972  Uganda    Africa  1972.0   51.016  10190285.0   950.735869
# 1973     NaN       NaN     NaN      NaN         NaN          NaN
# 1974     NaN       NaN     NaN      NaN         NaN          NaN
# 1975     NaN       NaN     NaN      NaN         NaN          NaN
# 1976     NaN       NaN     NaN      NaN         NaN          NaN
# 1977  Uganda    Africa  1977.0   50.350  11457758.0   843.733137
# 1978     NaN       NaN     NaN      NaN         NaN          NaN
# 1979     NaN       NaN     NaN      NaN         NaN          NaN
# 1980     NaN       NaN     NaN      NaN         NaN          NaN
# 1981     NaN       NaN     NaN      NaN         NaN          NaN
# 1982  Uganda    Africa  1982.0   49.849  12939400.0   682.266227
# 1983     NaN       NaN     NaN      NaN         NaN          NaN
# 1984     NaN       NaN     NaN      NaN         NaN          NaN
# 1985     NaN       NaN     NaN      NaN         NaN          NaN
# 1986     NaN       NaN     NaN      NaN         NaN          NaN
# 1987  Uganda    Africa  1987.0   51.509  15283050.0   617.724406
# 1988     NaN       NaN     NaN      NaN         NaN          NaN
# 1989     NaN       NaN     NaN      NaN         NaN          NaN
# 1990     NaN       NaN     NaN      NaN         NaN          NaN
# 1991     NaN       NaN     NaN      NaN         NaN          NaN
# 1992  Uganda    Africa  1992.0   48.825  18252190.0   644.170797
# 1993     NaN       NaN     NaN      NaN         NaN          NaN
# 1994     NaN       NaN     NaN      NaN         NaN          NaN
# 1995     NaN       NaN     NaN      NaN         NaN          NaN
# 1996     NaN       NaN     NaN      NaN         NaN          NaN
# 1997  Uganda    Africa  1997.0   44.578  21210254.0   816.559081
# 1998     NaN       NaN     NaN      NaN         NaN          NaN
# 1999     NaN       NaN     NaN      NaN         NaN          NaN
# 2000     NaN       NaN     NaN      NaN         NaN          NaN
# 2001     NaN       NaN     NaN      NaN         NaN          NaN
# 2002  Uganda    Africa  2002.0   47.813  24739869.0   927.721002
# 2003     NaN       NaN     NaN      NaN         NaN          NaN
# 2004     NaN       NaN     NaN      NaN         NaN          NaN
# 2005     NaN       NaN     NaN      NaN         NaN          NaN
# 2006     NaN       NaN     NaN      NaN         NaN          NaN
# 2007  Uganda    Africa  2007.0   51.542  29170398.0  1056.380121
# 2008     NaN       NaN     NaN      NaN         NaN          NaN
# 2009     NaN       NaN     NaN      NaN         NaN          NaN
